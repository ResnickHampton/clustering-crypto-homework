# %% [markdown]
#  # Clustering Crypto

# %% [markdown]
#  ## Installing External Libraries

# %%
# Install the altair plotting library: https://altair-viz.github.io/
# !pip install -U altair
# Out:
# Collecting altair
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
#      |████████████████████████████████| 727 kB 661 kB/s eta 0:00:01
# Requirement already satisfied: jinja2 in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from altair) (2.11.3)
# Requirement already satisfied: entrypoints in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from altair) (0.3)
# Requirement already satisfied: jsonschema in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from altair) (3.2.0)
# Requirement already satisfied: toolz in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from altair) (0.11.1)
# Requirement already satisfied: pandas>=0.18 in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from altair) (1.2.3)
# Requirement already satisfied: numpy in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from altair) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.18->altair) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.18->altair) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (20.3.0)
# Requirement already satisfied: setuptools in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (52.0.0.post20210125)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/RES/opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (0.17.3)
# Installing collected packages: altair
# Successfully installed altair-4.1.0
# WARNING: You are using pip version 21.1.2; however, version 21.1.3 is available.
# You should consider upgrading via the '/Users/RES/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# Initial imports
import requests
import pandas as pd
import altair as alt
from pathlib import Path
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"
response = requests.get(url).json()

# %%
# Create a DataFrame
crypto_df = pd.DataFrame(response['Data']).T
crypto_df.head()
# Out:
#          Id                  Url                         ImageUrl  \
# 42     4321   /coins/42/overview           /media/35650717/42.jpg
# 300  749869  /coins/300/overview          /media/27010595/300.png
# 365   33639  /coins/365/overview            /media/352070/365.png
# 404   21227  /coins/404/overview  /media/35650851/404-300x300.jpg
# 433  926547  /coins/433/overview          /media/34836095/433.png
#
#     ContentCreatedOn Name Symbol   CoinName         FullName  \
# 42        1427211129   42     42    42 Coin     42 Coin (42)
# 300       1517935016  300    300  300 token  300 token (300)
# 365       1480032918  365    365    365Coin    365Coin (365)
# 404       1466100361  404    404    404Coin    404Coin (404)
# 433       1541597321  433    433  433 Token  433 Token (433)
#
#                                            Description AssetTokenStatus  ...  \
# 42   Everything about 42 coin is 42 - apart from th...              N/A  ...
# 300  300 token is an ERC20 token. This Token was cr...              N/A  ...
# 365  365Coin is a Proof of Work and Proof of Stake ...              N/A  ...
# 404  404 is a PoW/PoS hybrid cryptocurrency that al...              N/A  ...
# 433  433 Token is a decentralised soccer platform t...         Finished  ...
#
#     AssetLaunchDate MaxSupply MktCapPenalty IsUsedInDefi IsUsedInNft  \
# 42       0000-00-00         0             0            0           0
# 300      2017-07-01       300             0            0           0
# 365      0000-00-00         0             0            0           0
# 404      0000-00-00         0             0            0           0
# 433             NaN       NaN           NaN          NaN         NaN
#
#     PlatformType BuiltOn                        SmartContractAddress  \
# 42           NaN     NaN                                         NaN
# 300        token     ETH  0xaec98a708810414878c3bcdf46aad31ded4a4557
# 365          NaN     NaN                                         NaN
# 404          NaN     NaN                                         NaN
# 433          NaN     NaN                                         NaN
#
#     DecimalPoints Difficulty
# 42            NaN        NaN
# 300            18        NaN
# 365           NaN        NaN
# 404           NaN        NaN
# 433           NaN        NaN
#
# [5 rows x 32 columns]

# %%
# Alternatively, use the provided csv file:
file_path = Path("Resources/crypto_data.csv")

# Create a DataFrame
crypto_df = pd.read_csv(file_path, index_col=0)
crypto_df.head(10)
# Out:
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %% [markdown]
#  ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df=crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply']]
crypto_df.head(10)
# Out:
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df[crypto_df["IsTrading"] == True]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1144, 6)
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df[crypto_df["Algorithm"] != "N/A"]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1144, 6)
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# Remove the "IsTrading" column
crypto_df.drop("IsTrading", axis=1, inplace=True)
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1144, 5)
#        CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 365     365Coin       X11   PoW/PoS              NaN      2300000000
# 404     404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 611   SixEleven   SHA-256       PoW              NaN          611000
# 808         808   SHA-256   PoW/PoS     0.000000e+00               0
# 1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 2015  2015 coin       X11   PoW/PoS              NaN               0
# BTC     Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# ETH    Ethereum    Ethash       PoW     1.076842e+08               0
# LTC    Litecoin    Scrypt       PoW     6.303924e+07        84000000

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna(axis=0, how="any")
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (685, 5)
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 808                808         SHA-256   PoW/PoS     0.000000e+00
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 808                0
# 1337    314159265359
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000

# %%
# Remove rows with cryptocurrencies withouhaving no coins mined
crypto_df = crypto_df[crypto_df["TotalCoinsMined"] > 0]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (532, 5)
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
# ZEC              ZCash        Equihash       PoW     7.383056e+06
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 1337    314159265359
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000
# ZEC         21000000

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df[crypto_df.iloc[:] != 'N/A'].dropna()
crypto_df.head(10)
# Out:
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
# ZEC              ZCash        Equihash       PoW     7.383056e+06
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 1337    314159265359
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000
# ZEC         21000000

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coins_name = pd.DataFrame(crypto_df["CoinName"], index=crypto_df.index)
print(coins_name.shape)
coins_name.head()
# Out:
# (532, 1)
#        CoinName
# 42      42 Coin
# 404     404Coin
# 1337  EliteCoin
# BTC     Bitcoin
# ETH    Ethereum

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop("CoinName", axis=1)
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (532, 4)
#            Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42            Scrypt   PoW/PoS     4.199995e+01              42
# 404           Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337             X13   PoW/PoS     2.927942e+10    314159265359
# BTC          SHA-256       PoW     1.792718e+07        21000000
# ETH           Ethash       PoW     1.076842e+08               0
# LTC           Scrypt       PoW     6.303924e+07        84000000
# DASH             X11   PoW/PoS     9.031294e+06        22000000
# XMR   CryptoNight-V7       PoW     1.720114e+07               0
# ETC           Ethash       PoW     1.133597e+08       210000000
# ZEC         Equihash       PoW     7.383056e+06        21000000

# %%
# Create dummy variables for text features
X = pd.get_dummies(data=crypto_df, columns=["Algorithm", "ProofType"])
print(X.shape)
X.head(10)
# Out:
# (532, 98)
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# LTC      6.303924e+07        84000000                                 0
# DASH     9.031294e+06        22000000                                 0
# XMR      1.720114e+07               0                                 0
# ETC      1.133597e+08       210000000                                 0
# ZEC      7.383056e+06        21000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                0                  0                   0                0
# 404               0                  0                   0                0
# 1337              0                  0                   0                0
# BTC               0                  0                   0                0
# ETH               0                  0                   0                0
# LTC               0                  0                   0                0
# DASH              0                  0                   0                0
# XMR               0                  0                   0                0
# ETC               0                  0                   0                0
# ZEC               0                  0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# 42                    0                  0              0  ...
# 404                   0                  0              0  ...
# 1337                  0                  0              0  ...
# BTC                   0                  0              0  ...
# ETH                   0                  0              0  ...
# LTC                   0                  0              0  ...
# DASH                  0                  0              0  ...
# XMR                   0                  0              0  ...
# ETC                   0                  0              0  ...
# ZEC                   0                  0              0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 42                    1                   0                  0
# 404                   1                   0                  0
# 1337                  1                   0                  0
# BTC                   0                   0                  0
# ETH                   0                   0                  0
# LTC                   0                   0                  0
# DASH                  1                   0                  0
# XMR                   0                   0                  0
# ETC                   0                   0                  0
# ZEC                   0                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 42                     0              0                             0
# 404                    0              0                             0
# 1337                   0              0                             0
# BTC                    0              0                             0
# ETH                    0              0                             0
# LTC                    0              0                             0
# DASH                   0              0                             0
# XMR                    0              0                             0
# ETC                    0              0                             0
# ZEC                    0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 42                           0               0
# 404                          0               0
# 1337                         0               0
# BTC                          0               0
# ETH                          0               0
# LTC                          0               0
# DASH                         0               0
# XMR                          0               0
# ETC                          0               0
# ZEC                          0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 42                                 0                   0
# 404                                0                   0
# 1337                               0                   0
# BTC                                0                   0
# ETH                                0                   0
# LTC                                0                   0
# DASH                               0                   0
# XMR                                0                   0
# ETC                                0                   0
# ZEC                                0                   0
#
# [10 rows x 98 columns]

# %%
# Standardize data
X = StandardScaler().fit_transform(X)
X[:5]
# Out:
# array([[-0.11710817, -0.1528703 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.07530656, -0.0433963 , -0.06142951, -0.06142951,
#         -0.0433963 , -0.0433963 , -0.19245009, -0.06142951, -0.09740465,
#         -0.0433963 , -0.11547005, -0.07530656, -0.0433963 , -0.0433963 ,
#         -0.15191091, -0.0433963 , -0.13118084, -0.0433963 , -0.0433963 ,
#         -0.08703883, -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.08703883, -0.08703883, -0.08703883,
#         -0.0433963 , -0.13118084, -0.13840913, -0.13840913, -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.07530656, -0.18168574, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.07530656, -0.15826614, -0.31491833,
#         -0.0433963 , -0.08703883, -0.07530656, -0.06142951,  1.38675049,
#         -0.0433963 , -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.39879994, -0.0433963 , -0.18168574, -0.0433963 ,
#         -0.08703883, -0.08703883, -0.10680283, -0.0433963 , -0.13118084,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.07530656,
#         -0.43911856, -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#         -0.89632016, -0.0433963 , -0.0433963 ,  1.42222617, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.145009  , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.07530656, -0.0433963 , -0.06142951, -0.06142951,
#         -0.0433963 , -0.0433963 , -0.19245009, -0.06142951, -0.09740465,
#         -0.0433963 , -0.11547005, -0.07530656, -0.0433963 , -0.0433963 ,
#         -0.15191091, -0.0433963 , -0.13118084, -0.0433963 , -0.0433963 ,
#         -0.08703883, -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.08703883, -0.08703883, -0.08703883,
#         -0.0433963 , -0.13118084, -0.13840913, -0.13840913, -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.07530656, -0.18168574, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.07530656, -0.15826614, -0.31491833,
#         -0.0433963 , -0.08703883, -0.07530656, -0.06142951,  1.38675049,
#         -0.0433963 , -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.39879994, -0.0433963 , -0.18168574, -0.0433963 ,
#         -0.08703883, -0.08703883, -0.10680283, -0.0433963 , -0.13118084,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.07530656,
#         -0.43911856, -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#         -0.89632016, -0.0433963 , -0.0433963 ,  1.42222617, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 ],
#        [ 0.52494561,  4.48942416, -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.07530656, -0.0433963 , -0.06142951, -0.06142951,
#         -0.0433963 , -0.0433963 , -0.19245009, -0.06142951, -0.09740465,
#         -0.0433963 , -0.11547005, -0.07530656, -0.0433963 , -0.0433963 ,
#         -0.15191091, -0.0433963 , -0.13118084, -0.0433963 , -0.0433963 ,
#         -0.08703883, -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.08703883, -0.08703883, -0.08703883,
#         -0.0433963 , -0.13118084, -0.13840913, -0.13840913, -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.07530656, -0.18168574, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.07530656, -0.15826614, -0.31491833,
#         -0.0433963 , -0.08703883, -0.07530656, -0.06142951, -0.72111026,
#         -0.0433963 , -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.39879994, -0.0433963 ,  5.50400923, -0.0433963 ,
#         -0.08703883, -0.08703883, -0.10680283, -0.0433963 , -0.13118084,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.07530656,
#         -0.43911856, -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#         -0.89632016, -0.0433963 , -0.0433963 ,  1.42222617, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 ],
#        [-0.11671506, -0.15255998, -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.07530656, -0.0433963 , -0.06142951, -0.06142951,
#         -0.0433963 , -0.0433963 , -0.19245009, -0.06142951, -0.09740465,
#         -0.0433963 , -0.11547005, -0.07530656, -0.0433963 , -0.0433963 ,
#         -0.15191091, -0.0433963 , -0.13118084, -0.0433963 , -0.0433963 ,
#         -0.08703883, -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.08703883, -0.08703883, -0.08703883,
#         -0.0433963 , -0.13118084, -0.13840913, -0.13840913, -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.07530656, -0.18168574, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.07530656, -0.15826614,  3.17542648,
#         -0.0433963 , -0.08703883, -0.07530656, -0.06142951, -0.72111026,
#         -0.0433963 , -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.39879994, -0.0433963 , -0.18168574, -0.0433963 ,
#         -0.08703883, -0.08703883, -0.10680283, -0.0433963 , -0.13118084,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.07530656,
#         -0.43911856, -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#          1.11567277, -0.0433963 , -0.0433963 , -0.70312305, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 ],
#        [-0.11474682, -0.1528703 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.07530656, -0.0433963 , -0.06142951, -0.06142951,
#         -0.0433963 , -0.0433963 , -0.19245009, -0.06142951, -0.09740465,
#         -0.0433963 , -0.11547005, -0.07530656, -0.0433963 , -0.0433963 ,
#         -0.15191091, -0.0433963 ,  7.62306442, -0.0433963 , -0.0433963 ,
#         -0.08703883, -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.08703883, -0.08703883, -0.08703883,
#         -0.0433963 , -0.13118084, -0.13840913, -0.13840913, -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.07530656, -0.18168574, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.07530656, -0.15826614, -0.31491833,
#         -0.0433963 , -0.08703883, -0.07530656, -0.06142951, -0.72111026,
#         -0.0433963 , -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.39879994, -0.0433963 , -0.18168574, -0.0433963 ,
#         -0.08703883, -0.08703883, -0.10680283, -0.0433963 , -0.13118084,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.07530656,
#         -0.43911856, -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#          1.11567277, -0.0433963 , -0.0433963 , -0.70312305, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 ]])

# %% [markdown]
#  ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimension to 3 principal components
n_comp = 3
pca = PCA(n_components=n_comp)
principal_components = pca.fit_transform(X)
principal_components
# Out:
# array([[-0.33879896,  1.04535244, -0.38805724],
#        [-0.32216644,  1.04540638, -0.38846142],
#        [ 2.30307127,  1.72598282, -0.45178531],
#        ...,
#        [ 0.33092061, -2.27221376,  0.23934434],
#        [-0.14510201, -2.20444043,  0.17361373],
#        [-0.30300835,  0.77148726, -0.18465992]])

# %%
# Create a DataFrame with the principal components data
col_names = [f"PC {i}" for i in range(1, n_comp + 1)]
pcs_df = pd.DataFrame(principal_components, columns=col_names, index=crypto_df.index)
print(pcs_df.shape)
pcs_df.head(10)
# Out:
# (532, 3)
#           PC 1      PC 2      PC 3
# 42   -0.338799  1.045352 -0.388057
# 404  -0.322166  1.045406 -0.388461
# 1337  2.303071  1.725983 -0.451785
# BTC  -0.146854 -1.344014  0.130633
# ETH  -0.142417 -1.998074  0.233322
# LTC  -0.167361 -1.143326 -0.043370
# DASH -0.389598  1.329748 -0.276230
# XMR  -0.148973 -2.236929  0.295838
# ETC  -0.140861 -1.998179  0.233298
# ZEC  -0.145101 -2.204440  0.173614

# %% [markdown]
#  ### Clustering Crytocurrencies Using K-Means
#
#  #### Finde the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
alt.Chart(df_elbow).mark_line().encode(x="k", y="inertia")
# Out:
# alt.Chart(...)

# %% [markdown]
#  Running K-Means with `k=4`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
clustered_df = pd.concat([crypto_df, pcs_df], axis=1, sort=False)
clustered_df["CoinName"] = coins_name["CoinName"]
clustered_df["Class"] = model.labels_
print(clustered_df.shape)
clustered_df.head(10)
# Out:
# (532, 9)
#            Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1  \
# 42            Scrypt   PoW/PoS     4.199995e+01              42 -0.338799
# 404           Scrypt   PoW/PoS     1.055185e+09       532000000 -0.322166
# 1337             X13   PoW/PoS     2.927942e+10    314159265359  2.303071
# BTC          SHA-256       PoW     1.792718e+07        21000000 -0.146854
# ETH           Ethash       PoW     1.076842e+08               0 -0.142417
# LTC           Scrypt       PoW     6.303924e+07        84000000 -0.167361
# DASH             X11   PoW/PoS     9.031294e+06        22000000 -0.389598
# XMR   CryptoNight-V7       PoW     1.720114e+07               0 -0.148973
# ETC           Ethash       PoW     1.133597e+08       210000000 -0.140861
# ZEC         Equihash       PoW     7.383056e+06        21000000 -0.145101
#
#           PC 2      PC 3          CoinName  Class
# 42    1.045352 -0.388057           42 Coin      0
# 404   1.045406 -0.388461           404Coin      0
# 1337  1.725983 -0.451785         EliteCoin      0
# BTC  -1.344014  0.130633           Bitcoin      3
# ETH  -1.998074  0.233322          Ethereum      3
# LTC  -1.143326 -0.043370          Litecoin      3
# DASH  1.329748 -0.276230              Dash      0
# XMR  -2.236929  0.295838            Monero      3
# ETC  -1.998179  0.233298  Ethereum Classic      3
# ZEC  -2.204440  0.173614             ZCash      3

# %% [markdown]
#  ### Visualizing Results
#
#  #### Scatter Plot for Clusters

# %%
# Scatter plot to visualize clusters using two principal components
alt.Chart(clustered_df).mark_circle(size=60).encode(
    x="PC 1",
    y="PC 2",
    color=alt.Color(
        "Class",
        scale=alt.Scale(domain=[0, 1, 2, 3], range=["red", "green", "blue", "orange"]),
    ),
    tooltip=["CoinName", "Algorithm", "TotalCoinsMined", "TotalCoinSupply"],
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
#  #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
mm_scaler = MinMaxScaler()
plot_data = mm_scaler.fit_transform(
    clustered_df[["TotalCoinSupply", "TotalCoinsMined"]]
)
plot_df = pd.DataFrame(
    plot_data, columns=["TotalCoinSupply", "TotalCoinsMined"], index=clustered_df.index
)
plot_df["CoinName"] = clustered_df["CoinName"]
plot_df["Class"] = clustered_df["Class"]
plot_df.head()
# Out:
#       TotalCoinSupply  TotalCoinsMined   CoinName  Class
# 42       4.200000e-11         0.000000    42 Coin      0
# 404      5.320000e-04         0.001066    404Coin      0
# 1337     3.141593e-01         0.029576  EliteCoin      0
# BTC      2.100000e-05         0.000018    Bitcoin      3
# ETH      0.000000e+00         0.000109   Ethereum      3

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
alt.Chart(plot_df).mark_circle(size=60).encode(
    x="TotalCoinsMined",
    y="TotalCoinSupply",
    color=alt.Color(
        "Class",
        scale=alt.Scale(domain=[0, 1, 2, 3], range=["red", "green", "blue", "orange"]),
    ),
    tooltip=["CoinName", "TotalCoinsMined", "TotalCoinSupply"],
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
#  #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(
        clustered_df[
            [
                "CoinName",
                "Algorithm",
                "ProofType",
                "TotalCoinSupply",
                "TotalCoinsMined",
                "Class",
            ]
        ]
    )
# Out:
#                                 CoinName               Algorithm  \
# 42                               42 Coin                  Scrypt
# 404                              404Coin                  Scrypt
# 1337                           EliteCoin                     X13
# BTC                              Bitcoin                 SHA-256
# ETH                             Ethereum                  Ethash
# LTC                             Litecoin                  Scrypt
# DASH                                Dash                     X11
# XMR                               Monero          CryptoNight-V7
# ETC                     Ethereum Classic                  Ethash
# ZEC                                ZCash                Equihash
# BTS                            Bitshares                 SHA-512
# DGB                             DigiByte                Multiple
# BTCD                         BitcoinDark                 SHA-256
# XPY                              PayCoin                 SHA-256
# PRC                          ProsperCoin                  Scrypt
# KOBO                            KoboCoin                     X15
# SPR                           Spreadcoin                     X11
# ARG                             Argentum                  Scrypt
# AUR                          Aurora Coin                  Scrypt
# BLU                             BlueCoin                  Scrypt
# XMY                           MyriadCoin                Multiple
# MOON                            MoonCoin                  Scrypt
# ZET                             ZetaCoin                 SHA-256
# SXC                              SexCoin                  Scrypt
# QTL                              Quatloo                  Scrypt
# ENRG                          EnergyCoin                  Scrypt
# QRK                            QuarkCoin                   Quark
# RIC                              Riecoin                 Groestl
# DGC                         Digitalcoin                   Scrypt
# BTB                               BitBar                  Scrypt
# CAT                              Catcoin                  Scrypt
# CBX                        CryptoBullion                  Scrypt
# CCN                            CannaCoin                  Scrypt
# CRYPT                          CryptCoin                     X11
# CSC                           CasinoCoin                  Scrypt
# DMD                              Diamond                 Groestl
# XVG                                Verge                Multiple
# DVC                              DevCoin                 SHA-256
# EAC                            EarthCoin                  Scrypt
# EFL                             E-Gulden                  Scrypt
# EMC2                         Einsteinium                  Scrypt
# EMD                              Emerald                  Scrypt
# EXCL                      Exclusive Coin                     PoS
# FLT                          FlutterCoin                  Scrypt
# FRK                               Franko                  Scrypt
# FTC                          FeatherCoin               NeoScrypt
# GDC                            GrandCoin                  Scrypt
# GLC                           GlobalCoin                  Scrypt
# GLD                             GoldCoin                  Scrypt
# HBN                          HoboNickels                  Scrypt
# HYP                           HyperStake                     X11
# IFC                        Infinite Coin                  Scrypt
# IOC                               IOCoin                     X11
# IXC                               IXcoin                 SHA-256
# KGC                           KrugerCoin                  Scrypt
# LKY                            LuckyCoin                  Scrypt
# LTB                             Litebar                   Scrypt
# MAX                              MaxCoin                    SHA3
# MEC                             MegaCoin                  Scrypt
# MED                    MediterraneanCoin     HybridScryptHash256
# MINT                            MintCoin                  Scrypt
# MINC                             MinCoin                  Scrypt
# MZC                             MazaCoin                 SHA-256
# NAUT                       Nautilus Coin                  Scrypt
# NAV                              NavCoin                     X13
# NOBL                           NobleCoin                  Scrypt
# NMC                             Namecoin                 SHA-256
# NYAN                            NyanCoin                  Scrypt
# OPAL                            OpalCoin                     X13
# ORB                            Orbitcoin               NeoScrypt
# POT                              PotCoin                  Scrypt
# PXC                          PhoenixCoin                  Scrypt
# RDD                             Reddcoin                  Scrypt
# RPC                          RonPaulCoin                  Scrypt
# SBC                           StableCoin                  Scrypt
# SMC                            SmartCoin                  Scrypt
# SUPER                          SuperCoin                     X11
# SYNC                            SyncCoin                     X11
# SYS                              SysCoin                 SHA-256
# TES                            TeslaCoin                Multiple
# TGC                            TigerCoin                 SHA-256
# TIT                           TittieCoin                 PHI1612
# TOR                              TorCoin                     X11
# TRC                            TerraCoin                 SHA-256
# UNB                      UnbreakableCoin                 SHA-256
# UNO                           Unobtanium                 SHA-256
# URO                              UroCoin                     X11
# USDE                UnitaryStatus Dollar                  Scrypt
# UTC                            UltraCoin                  Scrypt
# VIA                              ViaCoin                  Scrypt
# VRC                             VeriCoin                  Scrypt
# VTC                             Vertcoin               Lyra2REv2
# WDC                            WorldCoin                  Scrypt
# XC                              X11 Coin                     X11
# XCR                               Crypti                Multiple
# XJO                            JouleCoin                 SHA-256
# XST                          StealthCoin                     X13
# ZCC                             ZCC Coin                  Scrypt
# BCN                             ByteCoin             CryptoNight
# XDN                         DigitalNote              CryptoNight
# BURST                          BurstCoin               Shabal256
# SJCX                           StorjCoin            Counterparty
# MONA                            MonaCoin                  Scrypt
# NTRN                             Neutron                 SHA-256
# FAIR                            FairCoin                 Groestl
# NLG                               Gulden                  Scrypt
# RBY                             RubyCoin                  Scrypt
# PTC                           PesetaCoin                  Scrypt
# KORE                                Kore                     X13
# WBB                      Wild Beast Coin                  Scrypt
# NOTE                              Dnotes                  Scrypt
# FLO                                  Flo                  Scrypt
# 8BIT                           8BIT Coin                  Scrypt
# STV                          Sativa Coin                     X13
# ABY                              ArtByte                  Scrypt
# FLDC                        Folding Coin        Stanford Folding
# U                                  Ucoin                     X11
# UIS                               Unitus                Multiple
# CYP                       CypherPunkCoin                   QuBit
# OMC                             OmniCron                  Scrypt
# VTR                             Vtorrent                  Scrypt
# GRE                            GreenCoin                  Scrypt
# XCN                           Cryptonite                  M7 POW
# MSC                           MasterCoin                  Scrypt
# SOON                            SoonCoin                 SHA-256
# 1CR                              1Credit                  Scrypt
# ISL                             IslaCoin                     X11
# NXS                                Nexus                    SHA3
# MARS                           MarsCoin                      X11
# CTO                               Crypto                 Lyra2RE
# ACP                     Anarchists Prime                 SHA-256
# DRZ                               Droidz                   QUAIT
# BSC                             BowsCoin                     X11
# SQL                          Squall Coin                     X11
# SONG                           Song Coin                  Scrypt
# ZNY                              BitZeny                  Scrypt
# DIGS                             Diggits                  Scrypt
# EXP                              Expanse                  Ethash
# CON                               Paycon                     X13
# SC                               Siacoin                 Blake2b
# EMC                             Emercoin                 SHA-256
# EGC                        EverGreenCoin                     X15
# MND                             MindCoin                     X11
# I0C                               I0coin                 SHA-256
# DCR                               Decred                BLAKE256
# RVR                        Revolution VR                  Scrypt
# HODL                            HOdlcoin  1GB AES Pattern Search
# EDRC                             EDRCoin                 SHA-256
# HTC                              Hitcoin                     X11
# GAME                         Gamecredits                  Scrypt
# DBIC                           DubaiCoin                 SHA-256
# DIEM                       CarpeDiemCoin                 SHA-256
# PWR                             PWR Coin                   NIST5
# BLRY                         BillaryCoin                  Scrypt
# GPU                             GPU Coin                  Scrypt
# ADZ                              Adzcoin                     X11
# SOIL                            SoilCoin                  Dagger
# YOC                               YoCoin                  Scrypt
# SIB                              SibCoin                 X11GOST
# ERC                           EuropeCoin                     X11
# ZEIT                            ZeitCoin                  Scrypt
# SWING                          SwingCoin                 SHA-256
# SAFEX                   SafeExchangeCoin                  Scrypt
# NEBU                      Nebuchadnezzar                     PoS
# FRN                               Francs                  Scrypt
# BOLI                         BolivarCoin                     X11
# XRA                             Ratecoin                     X11
# REV                               Revenu                 SHA-256
# CKC                            Clockcoin                 SHA-256
# VIP                           VIP Tokens                   NIST5
# BSD                              BitSend                     X11
# OMNI                                Omni                  Scrypt
# LIR                          Let it Ride                 POS 3.0
# PUT                            PutinCoin                  Scrypt
# IBANK                          iBankCoin                  Scrypt
# FRWC                      Frankywillcoin                  Scrypt
# MUDRA                          MudraCoin                     X13
# PIZZA                          PizzaCoin                     X11
# LC                         Lutetium Coin                     X11
# KMD                               Komodo                Equihash
# GB                            GoldBlocks                     X11
# CTC                           CarterCoin                  Scrypt
# KRB                                Karbo             CryptoNight
# BXT                            BitTokens                 SHA-256
# ZYD                            ZayedCoin                 SHA-256
# MST                          MustangCoin                     X11
# ZNE                             ZoneCoin                  Scrypt
# COVAL                  Circuits of Value                Multiple
# ROOT                            RootCoin                  Scrypt
# DOPE                            DopeCoin                  Scrypt
# BTCR                         BitCurrency                  Scrypt
# DLC                           DollarCoin                 SHA-256
# SCN                             Swiscoin                  Scrypt
# SH                              Shilling                  Scrypt
# BUZZ                            BuzzCoin                SHA-256D
# XPO                                Opair                     PoS
# PSB                              PesoBit                  Scrypt
# HALLO                     Halloween Coin                     X11
# XZC                                ZCoin                  Lyra2Z
# CFC                           CoffeeCoin                     PoS
# ROYAL                          RoyalCoin                     X13
# GNJ                         GanjaCoin V2                     X14
# TEAM                              TeamUP                     PoS
# LANA                            LanaCoin                SHA-256D
# ELE                           Elementrem                  Ethash
# ZCL                             ZClassic                Equihash
# ARK                                  ARK                    DPoS
# INSANE                        InsaneCoin                     X11
# KLC                             KiloCoin                  Scrypt
# ATX                            ArtexCoin                     X11
# EMB                            EmberCoin                     X13
# XEN                            XenixCoin                     X11
# FRE                             FreeCoin                     PoS
# PLNC                             PLNCoin                  Scrypt
# ARCO                        AquariusCoin                  Scrypt
# KURT                             Kurrent                     X11
# XCRE                             Creatio                     PoS
# ENT                             Eternity                     X11
# EUC                             Eurocoin                 SHA-256
# BCF                          BitcoinFast                  Scrypt
# XSN                             Stakenet                     X11
# BCCOIN                   BitConnect Coin                  Scrypt
# MONEY                          MoneyCoin                  Scrypt
# XNG                               Enigma                     X11
# XCI               Cannabis Industry Coin             CryptoNight
# RC                            Russiacoin                  Scrypt
# PND                            PandaCoin                  Scrypt
# UNITS                          GameUnits                  Scrypt
# GAKH                            GAKHcoin                  Scrypt
# ASAFE2                           Allsafe                   Quark
# LTCR                           LiteCreed                   QuBit
# OS76                          OsmiumCoin                  Scrypt
# BIC                           Bikercoins             CryptoNight
# HXX                             HexxCoin                 Lyra2RE
# KED                Klingon Empire Darsek                  Scrypt
# IOP                   Internet of People                 SHA-256
# KUSH                            KushCoin                     X11
# PRX                           Printerium                  Scrypt
# PAC                              PacCoin                     X11
# IMPCH                            Impeach                  Scrypt
# CTL                              Citadel          CryptoNight-V7
# ZBC                           Zilbercoin                  Scrypt
# FRST                           FirstCoin                  Scrypt
# BVC                           BeaverCoin                  Scrypt
# FIND                            FindCoin                     X13
# VLTC                           VaultCoin                     X11
# ZER                                 Zero                Equihash
# CHAT                            OpenChat                  Scrypt
# CDN                         Canada eCoin                  Scrypt
# ZOI                                 Zoin                 Lyra2RE
# RNS                            RenosCoin                  Scrypt
# DBIX                           DubaiCoin        Dagger-Hashimoto
# XVP                        VirtacoinPlus                     X11
# TAJ                              TajCoin                 Blake2S
# IMX                               Impact                     X11
# EB3                              EB3coin                  Scrypt
# ATMOS                              Atmos                     PoS
# HPC                            HappyCoin                     X11
# CXT                             Coinonat                   NIST5
# MCRN                          MacronCoin                     PoS
# RAIN                          Condensate                     X11
# IMS             Independent Money System                  Scrypt
# ARGUS                          ArgusCoin                  Scrypt
# LMC                             LomoCoin                  Scrypt
# PROC                         ProCurrency                 SHA-256
# XGR                          GoldReserve                     X11
# BENJI                         BenjiRolls                  Scrypt
# GRW                           GrowthCoin                  Scrypt
# ILC                               ILCoin                 SHA-256
# PHR                               Phreak                     PoS
# DEA                           Degas Coin                  Scrypt
# HTML5                         HTML5 Coin                     X15
# USC                 Ultimate Secure Cash                 SHA-256
# EQT                           EquiTrader                  Scrypt
# QTUM                                QTUM                 POS 3.0
# QRL             Quantum Resistant Ledger          CryptoNight-V7
# ESP                               Espers                     536
# DYN                              Dynamic                 Argon2d
# NANO                                Nano                 Blake2b
# CHAN                            ChanCoin              Cloverhash
# DCY                          Dinastycoin             CryptoNight
# DNR                             Denarius                   NIST5
# DP                          DigitalPrice                     X11
# VUC                    Virta Unique Coin                   NIST5
# BTPL                      Bitcoin Planet                   Skein
# UNIFY                              Unify                  Scrypt
# BRIT                            BritCoin                     X13
# SOCC                          SocialCoin                  Scrypt
# ARC                           ArcticCoin                     X11
# DAS                                  DAS                     X11
# LINDA                              Linda                  Scrypt
# XLC                           LeviarCoin             CryptoNight
# ONION                          DeepOnion                     X13
# BTX                              Bitcore             Time Travel
# GCN                             gCn Coin                  Scrypt
# SMART                          SmartCash                  Keccak
# SIGT                            Signatum     SkunkHash v2 Raptor
# ONX                                 Onix                     X11
# CRM                                Cream                   Skein
# BCH                         Bitcoin Cash                 SHA-256
# XMCC                             Monoeci                     X11
# DFT                            Draftcoin                  Scrypt
# VET                              Vechain   VeChainThor Authority
# SOJ                         Sojourn Coin                  Scrypt
# STCN                           Stakecoin                     PoS
# NYC                          NewYorkCoin                  Scrypt
# FRAZ                            FrazCoin                  Scrypt
# KRONE                          Kronecoin                  Scrypt
# ACC                               AdCoin                  Scrypt
# LINX                                Linx                  Scrypt
# XCXT                           CoinonatX                  Scrypt
# ETHD                       Ethereum Dark                  Scrypt
# SUMO                            Sumokoin             CryptoNight
# ODN                             Obsidian                 SHA-512
# ADA                              Cardano               Ouroboros
# REC                            Regalcoin                     X11
# BTCZ                            BitcoinZ                Equihash
# TZC                           TrezarCoin               NeoScrypt
# ELM                             Elements                     X11
# TER                        TerraNovaCoin                  Scrypt
# VIVO                           VIVO Coin               NeoScrypt
# RUP                                Rupee               Lyra2REv2
# BTG                         Bitcoin Gold                Equihash
# WOMEN                          WomenCoin                  Scrypt
# MAY                     Theresa May Coin                 SHA-256
# NAMO                            NamoCoin                   NIST5
# LUX                              LUXCoin                 PHI1612
# PIRL                                Pirl                  Dagger
# XIOS                                Xios                  Scrypt
# BTDX                        Bitcloud 2.0                   Quark
# EBST                              eBoost                  Scrypt
# KEK                              KekCoin                 POS 2.0
# BLHC                       BlackholeCoin                  Scrypt
# XIN                   Infinity Economics                 SHA-256
# PURA                                Pura                     X11
# INN                               Innova               NeoScrypt
# ELLA                             Ellaism                  Ethash
# GBX                               GoByte               NeoScrypt
# MAG                               Magnet                     X11
# TAU                           Lamden Tau                    DPoS
# ECA                              Electra                   NIST5
# BCD                      Bitcoin Diamond                     X13
# XSH                               SHIELD                Multiple
# CNBC                    Cash & Back Coin                  Scrypt
# XUN                            UltraNote             CryptoNight
# COAL                             BitCoal             CryptoNight
# DAXX                            DaxxCoin                  Ethash
# BWK                              Bulwark                   NIST5
# KLKS                            Kalkulus                   Quark
# AC3                                  AC3                     X11
# LTHN                             Lethean          CryptoNight-V7
# GER                           GermanCoin                  Scrypt
# LTCU                      LiteCoin Ultra                  Scrypt
# POP                          PopularCoin                  Scrypt
# PNX                             PhantomX                     X11
# PHO                               Photon                BLAKE256
# SUCR                               Sucre                     X11
# SPK                            SparksPay               NeoScrypt
# WAGE                            Digiwage                   Quark
# GUN                              GunCoin               NeoScrypt
# IRL                            IrishCoin                  Scrypt
# TROLL                          Trollcoin                  Scrypt
# LCP                        Litecoin Plus                  Scrypt
# MONK                      Monkey Project                     X11
# PCOIN                       Pioneer Coin                     X11
# UBTC                       UnitedBitcoin                 SHA-256
# ITZ                            Interzone                     C11
# TPAY                            TokenPay                 POS 3.0
# MCT     1717 Masonic Commemorative Token                  Ethash
# MBC                          My Big Coin                  Scrypt
# TRTL                          TurtleCoin             CryptoNight
# MUN                              MUNcoin               SkunkHash
# USX                Unified Society USDEX                  Scrypt
# NBR                          Niobio Cash             CryptoNight
# SSS                           ShareChain                  Scrypt
# TRF                           Travelflex                  Dagger
# KREDS                              KREDS               Lyra2REv2
# TOKC                          Tokyo Coin                     X13
# BBP                             BiblePay      Proof-of-BibleHash
# LCC                         LitecoinCash          SHA-256 + Hive
# FLIP                             BitFlip                  Scrypt
# LOT                            LottoCoin                  Scrypt
# CIF              Crypto Improvement Fund                     X11
# SPD                              Stipend                     C11
# POA                          Poa Network      Proof-of-Authority
# PUSHI                              Pushi                     X11
# ELP                             Ellerium                   XEVAN
# VLX                                Velox                  Scrypt
# ONT                             Ontology                    VBFT
# CLO                     Callisto Network                  Ethash
# TUBE                             BitTube             CryptoNight
# PSD                             Poseidon                  Scrypt
# ADK                         Aidos Kuneen                   IMesh
# BSX                             Bitspace                   NIST5
# BRIA                            Briacoin                  Scrypt
# IC                              Ignition                  Scrypt
# BTL                            Bitrolium                Equihash
# MEDIC                          MedicCoin                  Scrypt
# ALPS                     Alpenschillling                  Lyra2Z
# BITG                       Bitcoin Green          Green Protocol
# DEV                         Deviant Coin                     PoS
# ABJ                              Abjcoin                  Scrypt
# SEM                                Semux     Semux BFT consensus
# FTO                           FuturoCoin                     X11
# CARE                             Carebit                   Quark
# NZL                              Zealium                     PoS
# XMC                       Monero Classic             CryptoNight
# PROTON                            Proton                    X16R
# DEAL                           iDealCash                  Scrypt
# JUMP                            Jumpcoin                   NIST5
# INFX                             Infinex                 Lyra2RE
# XBI                    Bitcoin Incognito                   XEVAN
# KEC                                KEYCO                  Tribus
# HWC                        HollyWoodCoin                  Scrypt
# GIN                              GINcoin                  Lyra2Z
# PLTC                          PlatinCoin             CryptoNight
# LOKI                                Loki       CryptoNight Heavy
# NCP                          Newton Coin             CryptoNight
# SIC                            Swisscoin                  Scrypt
# XT3                                Xt3ch                  Scrypt
# MGD                             MassGrid    Jump Consistent Hash
# VIG                               TheVig                SHA-256D
# PLURA                          PluraCoin             CryptoNight
# EMAR                          EmaratCoin                  Scrypt
# DKD                               Dekado                     X15
# LYNX                                Lynx                  Scrypt
# POSQ                      Poseidon Quark                   Quark
# BWS                     BitcoinWSpectrum                 SHA-256
# MUSE                                Muse                    DPoS
# XMN                               Motion                    X16R
# PLUS1                        PlusOneCoin                 HMQ1725
# AXE                                  Axe                     X11
# TRVC                          Trivechain                    X16R
# DTEM                              Dystem                   Quark
# GIC                                Giant                   Quark
# PNY                           Peony Coin                  Scrypt
# ABS                        Absolute Coin               Lyra2REv2
# VITAE                              Vitae                   Quark
# HEX                              HexCoin                  Scrypt
# TPC                               TPCash                  Scrypt
# WEBC                            Webchain          CryptoNight-V7
# RYO                                  Ryo         Cryptonight-GPU
# URALS                         Urals Coin                   XEVAN
# QWC                           Qwertycoin       CryptoNight Heavy
# ARE                               ARENON                     X11
# EUNO                                EUNO                     X11
# MMO                              MMOCoin                  Scrypt
# KETAN                              Ketan                     PoS
# PPAI                         Project Pai                 SHA-256
# XDNA                                XDNA                  Keccak
# PAXEX                              PAXEX                     X11
# AZART                              Azart                     X11
# TSC                         ThunderStake                  Scrypt
# KCASH                              Kcash                 SHA-512
# XCG                              Xchange                    X16R
# AAC                    Acute Angle Cloud               ECC 256K1
# CRYP                         CrypticCoin                Equihash
# BTXC                         Bettex coin                   XEVAN
# ACM                             Actinium                  Lyra2Z
# BSV                           Bitcoin SV                 SHA-256
# BITM                            BitMoney                   XEVAN
# JMC                Junson Ming Chan Coin                     X11
# FRED                          FREDEnergy             CryptoNight
# HERB                            HerbCoin                   Quark
# UMO                   Universal Molecule                   Blake
# LIT                              Lithium                   Blake
# PIRATE                        PirateCash                Equihash
# EXO                               Exosis                  Exosis
# BLTG                         Block-Logic                  Scrypt
# OWC                                Oduwa                  Scrypt
# BEAM                                Beam                Equihash
# GALI                             Galilel                   Quark
# BTH                            Bithereum                Equihash
# CSPN                       Crypto Sports                   Quark
# CREDIT                            Credit                  Scrypt
# SLC                                SLICE                   QuBit
# DASHP                      Dash Platinum                     X11
# NSD                            Nasdacoin                  Scrypt
# BEET                         Beetle Coin                   XEVAN
# TTN                           Titan Coin                SHA-256D
# AWR                                Award                     X11
# BLAST                              BLAST                 SHA-256
# XRC                      Bitcoin Rhodium                     X13
# GLT                          GlobalToken                 SHA-256
# INSN                         Insane Coin                     X11
# ALX                                 ALAX                    DPoS
# LDOGE                           LiteDoge                  Scrypt
# SLR                            SolarCoin                  Scrypt
# TRK                            TruckCoin                     X11
# UFO                             UFO Coin               NeoScrypt
# OC                            OrangeCoin                  Scrypt
# BLC                            BlakeCoin                   Blake
# BITS                         BitstarCoin                  Scrypt
# NEOS                            NeosCoin                 SHA-256
# HYPER                          HyperCoin                  Scrypt
# PINK                            PinkCoin                     X11
# CESC                       Crypto Escudo                  Scrypt
# ADC                            AudioCoin                  Scrypt
# NKA                             IncaKoin                 SHA-256
# PIGGY                         Piggy Coin                     X11
# CRW                           Crown Coin                 SHA-256
# GEN                             Genstake                  Scrypt
# SMLY                          SmileyCoin                  Scrypt
# MI                            XiaoMiCoin                  Scrypt
# GRS                          Groestlcoin                 Groestl
# CPC                            CapriCoin                     X11
# CLUB                            ClubCoin                  Scrypt
# RADS                              Radium                     PoS
# BTA                                 Bata                  Scrypt
# PAK                              Pakcoin                  Scrypt
# CRB                           Creditbit                      X11
# OK                                OKCash                 SHA-256
# LSK                                 Lisk                    DPoS
# XHI                               HiCoin                  Scrypt
# XWC                            WhiteCoin                  Scrypt
# FSC                       FriendshipCoin               NeoScrypt
# J                               JoinCoin                Multiple
# TRI                       Triangles Coin                     X13
# VOLLAR                            Vollar         Equihash+Scrypt
# EOS                                  EOS                    DPoS
# RCC                        Reality Clash                  Ethash
# OXY                              Oxycoin                    DPoS
# TCH                            TigerCash                 SHA-256
# WAVES                              Waves              Leased POS
# PART                             Particl                     PoS
# BTT                           BitTorrent                   TRC10
# NXT                                  Nxt                     PoS
# ZEPH                              ZEPHYR                 SHA-256
# GAP                              Gapcoin                  Scrypt
# BDX                               Beldex             CryptoNight
# ZEN                              Horizen                Equihash
# XBC                          BitcoinPlus                  Scrypt
#
#                    ProofType    TotalCoinSupply  TotalCoinsMined  Class
# 42                   PoW/PoS                 42     4.199995e+01      0
# 404                  PoW/PoS          532000000     1.055185e+09      0
# 1337                 PoW/PoS       314159265359     2.927942e+10      0
# BTC                      PoW           21000000     1.792718e+07      3
